# %%
import datetime as dt
import numpy as np
import pandas as pd

# %%
FACIO_fileName=r'C:\Users\wangjuha\Desktop\Data Part 3 - resampled.csv'

# %%
New_fileName=r'C:\Users\wangjuha\Desktop\Data Part 3 - resampled - reindexed.csv'

# %%
df = pd.read_csv(FACIO_fileName)

# %%
df
# Out:
#             Timestamp  MultistackSourceSink GEOSupplyTemp(F)  \
# 0       1/1/2020 0:00                                    NaN
# 1       1/1/2020 0:15                                    NaN
# 2       1/1/2020 0:30                                    NaN
# 3       1/1/2020 0:45                                    NaN
# 4       1/1/2020 1:00                                    NaN
# ...               ...                                    ...
# 1489  1/16/2020 12:15                                    NaN
# 1490  1/16/2020 12:30                                    NaN
# 1491  1/16/2020 12:45                                    NaN
# 1492  1/16/2020 13:00                                    NaN
# 1493  1/16/2020 13:15                                    NaN
#
#       MultistackSourceSink GLYGEOFlow(gal/min)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# ...

# %%
df = df.set_index('Timestamp').asfreq('15Min')

# %%
df.to_csv(New_fileName,sep=',')
